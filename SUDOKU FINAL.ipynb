# %%
from tkinter import *

root = Tk()
root.geometry('450x500')
root.title('SUDOKUER')

a1 = Entry(root, width=6, borderwidth=1, relief='solid')
a1.insert(END,'0')
a1.grid(row=0, column=0)
a2 = Entry(root, width=6, borderwidth=1, relief='solid')
a2.insert(END,'0')
a2.grid(row=1, column=0)
a3 = Entry(root, width=6, borderwidth=1, relief='solid')
a3.insert(END,'0')
a3.grid(row=2, column=0)
a4 = Entry(root, width=6)
a4.insert(END,'0')
a4.grid(row=3, column=0)
a5 = Entry(root, width=6)
a5.insert(END,'0')
a5.grid(row=4, column=0)
a6 = Entry(root, width=6)
a6.insert(END,'0')
a6.grid(row=5, column=0)
a7 = Entry(root, width=6, borderwidth=1, relief='solid')
a7.insert(END,'0')
a7.grid(row=6, column=0)
a8 = Entry(root, width=6, borderwidth=1, relief='solid')
a8.insert(END,'0')
a8.grid(row=7, column=0)
a9 = Entry(root, width=6, borderwidth=1, relief='solid')
a9.insert(END,'0')
a9.grid(row=8, column=0)

b1 = Entry(root, width=6, borderwidth=1, relief='solid')
b1.insert(END,'0')
b1.grid(row=0, column=1)
b2 = Entry(root, width=6, borderwidth=1, relief='solid')
b2.insert(END,'0')
b2.grid(row=1, column=1)
b3 = Entry(root, width=6, borderwidth=1, relief='solid')
b3.insert(END,'0')
b3.grid(row=2, column=1)
b4 = Entry(root, width=6)
b4.insert(END,'0')
b4.grid(row=3, column=1)
b5 = Entry(root, width=6)
b5.insert(END,'0')
b5.grid(row=4, column=1)
b6 = Entry(root, width=6)
b6.insert(END,'0')
b6.grid(row=5, column=1)
b7 = Entry(root, width=6, borderwidth=1, relief='solid')
b7.insert(END,'0')
b7.grid(row=6, column=1)
b8 = Entry(root, width=6, borderwidth=1, relief='solid')
b8.insert(END,'0')
b8.grid(row=7, column=1)
b9 = Entry(root, width=6, borderwidth=1, relief='solid')
b9.insert(END,'0')
b9.grid(row=8, column=1)

c1 = Entry(root, width=6, borderwidth=1, relief='solid')
c1.insert(END,'0')
c1.grid(row=0, column=2)
c2 = Entry(root, width=6, borderwidth=1, relief='solid')
c2.insert(END,'0')
c2.grid(row=1, column=2)
c3 = Entry(root, width=6, borderwidth=1, relief='solid')
c3.insert(END,'0')
c3.grid(row=2, column=2)
c4 = Entry(root, width=6)
c4.insert(END,'0')
c4.grid(row=3, column=2)
c5 = Entry(root, width=6)
c5.insert(END,'0')
c5.grid(row=4, column=2)
c6 = Entry(root, width=6)
c6.insert(END,'0')
c6.grid(row=5, column=2)
c7 = Entry(root, width=6, borderwidth=1, relief='solid')
c7.insert(END,'0')
c7.grid(row=6, column=2)
c8 = Entry(root, width=6, borderwidth=1, relief='solid')
c8.insert(END,'0')
c8.grid(row=7, column=2)
c9 = Entry(root, width=6, borderwidth=1, relief='solid')
c9.insert(END,'0')
c9.grid(row=8, column=2)

d1 = Entry(root, width=6)
d1.insert(END,'0')
d1.grid(row=0, column=3)
d2 = Entry(root, width=6)
d2.insert(END,'0')
d2.grid(row=1, column=3)
d3 = Entry(root, width=6)
d3.insert(END,'0')
d3.grid(row=2, column=3)
d4 = Entry(root, width=6, borderwidth=1, relief='solid')
d4.insert(END,'0')
d4.grid(row=3, column=3)
d5 = Entry(root, width=6, borderwidth=1, relief='solid')
d5.insert(END,'0')
d5.grid(row=4, column=3)
d6 = Entry(root, width=6, borderwidth=1, relief='solid')
d6.insert(END,'0')
d6.grid(row=5, column=3)
d7 = Entry(root, width=6)
d7.insert(END,'0')
d7.grid(row=6, column=3)
d8 = Entry(root, width=6)
d8.insert(END,'0')
d8.grid(row=7, column=3)
d9 = Entry(root, width=6)
d9.insert(END,'0')
d9.grid(row=8, column=3)

e1 = Entry(root, width=6)
e1.insert(END,'0')
e1.grid(row=0, column=4)
e2 = Entry(root, width=6)
e2.insert(END,'0')
e2.grid(row=1, column=4)
e3 = Entry(root, width=6)
e3.insert(END,'0')
e3.grid(row=2, column=4)
e4 = Entry(root, width=6, borderwidth=1, relief='solid')
e4.insert(END,'0')
e4.grid(row=3, column=4)
e5 = Entry(root, width=6, borderwidth=1, relief='solid')
e5.insert(END,'0')
e5.grid(row=4, column=4)
e6 = Entry(root, width=6, borderwidth=1, relief='solid')
e6.insert(END,'0')
e6.grid(row=5, column=4)
e7 = Entry(root, width=6)
e7.insert(END,'0')
e7.grid(row=6, column=4)
e8 = Entry(root, width=6)
e8.insert(END,'0')
e8.grid(row=7, column=4)
e9 = Entry(root, width=6)
e9.insert(END,'0')
e9.grid(row=8, column=4)

f1 = Entry(root, width=6)
f1.insert(END,'0')
f1.grid(row=0, column=5)
f2 = Entry(root, width=6)
f2.insert(END,'0')
f2.grid(row=1, column=5)
f3 = Entry(root, width=6)
f3.insert(END,'0')
f3.grid(row=2, column=5)
f4 = Entry(root, width=6, borderwidth=1, relief='solid')
f4.insert(END,'0')
f4.grid(row=3, column=5)
f5 = Entry(root, width=6, borderwidth=1, relief='solid')
f5.insert(END,'0')
f5.grid(row=4, column=5)
f6 = Entry(root, width=6, borderwidth=1, relief='solid')
f6.insert(END,'0')
f6.grid(row=5, column=5)
f7 = Entry(root, width=6)
f7.insert(END,'0')
f7.grid(row=6, column=5)
f8 = Entry(root, width=6)
f8.insert(END,'0')
f8.grid(row=7, column=5)
f9 = Entry(root, width=6)
f9.insert(END,'0')
f9.grid(row=8, column=5)

g1 = Entry(root, width=6, borderwidth=1, relief='solid')
g1.insert(END,'0')
g1.grid(row=0, column=6)
g2 = Entry(root, width=6, borderwidth=1, relief='solid')
g2.insert(END,'0')
g2.grid(row=1, column=6)
g3 = Entry(root, width=6, borderwidth=1, relief='solid')
g3.insert(END,'0')
g3.grid(row=2, column=6)
g4 = Entry(root, width=6)
g4.insert(END,'0')
g4.grid(row=3, column=6)
g5 = Entry(root, width=6)
g5.insert(END,'0')
g5.grid(row=4, column=6)
g6 = Entry(root, width=6)
g6.insert(END,'0')
g6.grid(row=5, column=6)
g7 = Entry(root, width=6, borderwidth=1, relief='solid')
g7.insert(END,'0')
g7.grid(row=6, column=6)
g8 = Entry(root, width=6, borderwidth=1, relief='solid')
g8.insert(END,'0')
g8.grid(row=7, column=6)
g9 = Entry(root, width=6, borderwidth=1, relief='solid')
g9.insert(END,'0')
g9.grid(row=8, column=6)

h1 = Entry(root, width=6, borderwidth=1, relief='solid')
h1.insert(END,'0')
h1.grid(row=0, column=7)
h2 = Entry(root, width=6, borderwidth=1, relief='solid')
h2.insert(END,'0')
h2.grid(row=1, column=7)
h3 = Entry(root, width=6, borderwidth=1, relief='solid')
h3.insert(END,'0')
h3.grid(row=2, column=7)
h4 = Entry(root, width=6)
h4.insert(END,'0')
h4.grid(row=3, column=7)
h5 = Entry(root, width=6)
h5.insert(END,'0')
h5.grid(row=4, column=7)
h6 = Entry(root, width=6)
h6.insert(END,'0')
h6.grid(row=5, column=7)
h7 = Entry(root, width=6, borderwidth=1, relief='solid')
h7.insert(END,'0')
h7.grid(row=6, column=7)
h8 = Entry(root, width=6, borderwidth=1, relief='solid')
h8.insert(END,'0')
h8.grid(row=7, column=7)
h9 = Entry(root, width=6, borderwidth=1, relief='solid')
h9.insert(END,'0')
h9.grid(row=8, column=7)

i1 = Entry(root, width=6, borderwidth=1, relief='solid')
i1.insert(END,'0')
i1.grid(row=0, column=8)
i2 = Entry(root, width=6, borderwidth=1, relief='solid')
i2.insert(END,'0')
i2.grid(row=1, column=8)
i3 = Entry(root, width=6, borderwidth=1, relief='solid')
i3.insert(END,'0')
i3.grid(row=2, column=8)
i4 = Entry(root, width=6)
i4.insert(END,'0')
i4.grid(row=3, column=8)
i5 = Entry(root, width=6)
i5.insert(END,'0')
i5.grid(row=4, column=8)
i6 = Entry(root, width=6)
i6.insert(END,'0')
i6.grid(row=5, column=8)
i7 = Entry(root, width=6, borderwidth=1, relief='solid')
i7.insert(END,'0')
i7.grid(row=6, column=8)
i8 = Entry(root, width=6, borderwidth=1, relief='solid')
i8.insert(END,'0')
i8.grid(row=7, column=8)
i9 = Entry(root, width=6, borderwidth=1, relief='solid')
i9.insert(END,'0')
i9.grid(row=8, column=8)


def assign():
    A1=int(a1.get())
    A2=int(a2.get())
    A3=int(a3.get())
    A4=int(a4.get())
    A5=int(a5.get())
    A6=int(a6.get())
    A7=int(a7.get())
    A8=int(a8.get())
    A9=int(a9.get())

    B1=int(b1.get())
    B2=int(b2.get())
    B3=int(b3.get())
    B4=int(b4.get())
    B5=int(b5.get())
    B6=int(b6.get())
    B7=int(b7.get())
    B8=int(b8.get())
    B9=int(b9.get())

    C1=int(c1.get())
    C2=int(c2.get())
    C3=int(c3.get())
    C4=int(c4.get())
    C5=int(c5.get())
    C6=int(c6.get())
    C7=int(c7.get())
    C8=int(c8.get())
    C9=int(c9.get())

    D1=int(d1.get())
    D2=int(d2.get())
    D3=int(d3.get())
    D4=int(d4.get())
    D5=int(d5.get())
    D6=int(d6.get())
    D7=int(d7.get())
    D8=int(d8.get())
    D9=int(d9.get())

    E1=int(e1.get())
    E2=int(e2.get())
    E3=int(e3.get())
    E4=int(e4.get())
    E5=int(e5.get())
    E6=int(e6.get())
    E7=int(e7.get())
    E8=int(e8.get())
    E9=int(e9.get())

    F1=int(f1.get())
    F2=int(f2.get())
    F3=int(f3.get())
    F4=int(f4.get())
    F5=int(f5.get())
    F6=int(f6.get())
    F7=int(f7.get())
    F8=int(f8.get())
    F9=int(f9.get())

    G1=int(g1.get())
    G2=int(g2.get())
    G3=int(g3.get())
    G4=int(g4.get())
    G5=int(g5.get())
    G6=int(g6.get())
    G7=int(g7.get())
    G8=int(g8.get())
    G9=int(g9.get())

    H1=int(h1.get())
    H2=int(h2.get())
    H3=int(h3.get())
    H4=int(h4.get())
    H5=int(h5.get())
    H6=int(h6.get())
    H7=int(h7.get())
    H8=int(h8.get())
    H9=int(h9.get())

    I1=int(i1.get())
    I2=int(i2.get())
    I3=int(i3.get())
    I4=int(i4.get())
    I5=int(i5.get())
    I6=int(i6.get())
    I7=int(i7.get())
    I8=int(i8.get())
    I9=int(i9.get())

    def find_next_empty(puzzle):
    
        for r in range(9):
            for c in range(9):
                if puzzle[r][c] == 0:
                    return r,c
        return None, None

    def is_valid(puzzle, guess, row, col):

        row_vals = puzzle[row]
        if guess in row_vals:
            return False
        col_vals = [puzzle[i][col] for i in range(9)]
        if guess in col_vals:
            return False
        row_start = (row // 3) * 3
        col_start = (col // 3) * 3

        for r in range(row_start, row_start + 3):
            for c in range(col_start, col_start + 3):
                if puzzle[r][c] == guess:
                    return False
            
        return True

    def solve_sudoku(puzzle):

        row, col = find_next_empty(puzzle)

        if row is None:
            return True
        
        for guess in range(1,10):
            if is_valid(puzzle, guess, row, col):
                puzzle[row][col] = guess
                if solve_sudoku(puzzle):
                    return True
            puzzle[row][col] = 0
        return False

    Ans = [
            [A1,B1,C1,   D1,E1,F1,   G1,H1,I1],
            [A2,B2,C2,   D2,E2,F2,   G2,H2,I2],
            [A3,B3,C3,   D3,E3,F3,   G3,H3,I3],
            [A4,B4,C4,   D4,E4,F4,   G4,H4,I4],
            [A5,B5,C5,   D5,E5,F5,   G5,H5,I5],
            [A6,B6,C6,   D6,E6,F6,   G6,H6,I6],
            [A7,B7,C7,   D7,E7,F7,   G7,H7,I7],
            [A8,B8,C8,   D8,E8,F8,   G8,H8,I8],
            [A9,B9,C9,   D9,E9,F9,   G9,H9,I9]
        ]
    btn2=Button(root, text='SOLVED', width='5', height='1', command=solve_sudoku(Ans))
    btn2.grid(row=10,column=4)
    la1 = Label(text=Ans[0][0], borderwidth=1, relief='solid', width=6)
    la1.grid(row=11,column=0)
    lb1 = Label(text=Ans[0][1], borderwidth=1, relief='solid', width=6)
    lb1.grid(row=11,column=1)
    lc1 = Label(text=Ans[0][2], borderwidth=1, relief='solid', width=6)
    lc1.grid(row=11,column=2)
    ld1 = Label(text=Ans[0][3], width=6)
    ld1.grid(row=11,column=3)
    le1 = Label(text=Ans[0][4], width=6)
    le1.grid(row=11,column=4)
    lf1 = Label(text=Ans[0][5], width=6)
    lf1.grid(row=11,column=5)
    lg1 = Label(text=Ans[0][6], borderwidth=1, relief='solid', width=6)
    lg1.grid(row=11,column=6)
    lh1 = Label(text=Ans[0][7], borderwidth=1, relief='solid', width=6)
    lh1.grid(row=11,column=7)
    li1 = Label(text=Ans[0][8], borderwidth=1, relief='solid', width=6)
    li1.grid(row=11,column=8)

    la2 = Label(text=Ans[1][0], borderwidth=1, relief='solid', width=6)
    la2.grid(row=12,column=0)
    lb2 = Label(text=Ans[1][1], borderwidth=1, relief='solid', width=6)
    lb2.grid(row=12,column=1)
    lc2 = Label(text=Ans[1][2], borderwidth=1, relief='solid', width=6)
    lc2.grid(row=12,column=2)
    ld2 = Label(text=Ans[1][3], width=6)
    ld2.grid(row=12,column=3)
    le2 = Label(text=Ans[1][4], width=6)
    le2.grid(row=12,column=4)
    lf2 = Label(text=Ans[1][5], width=6)
    lf2.grid(row=12,column=5)
    lg2 = Label(text=Ans[1][6], borderwidth=1, relief='solid', width=6)
    lg2.grid(row=12,column=6)
    lh2 = Label(text=Ans[1][7], borderwidth=1, relief='solid', width=6)
    lh2.grid(row=12,column=7)
    li2 = Label(text=Ans[1][8], borderwidth=1, relief='solid', width=6)
    li2.grid(row=12,column=8)

    la3 = Label(text=Ans[2][0], borderwidth=1, relief='solid', width=6)
    la3.grid(row=13,column=0)
    lb3 = Label(text=Ans[2][1], borderwidth=1, relief='solid', width=6)
    lb3.grid(row=13,column=1)
    lc3 = Label(text=Ans[2][2], borderwidth=1, relief='solid', width=6)
    lc3.grid(row=13,column=2)
    ld3 = Label(text=Ans[2][3], width=6)
    ld3.grid(row=13,column=3)
    le3 = Label(text=Ans[2][4], width=6)
    le3.grid(row=13,column=4)
    lf3 = Label(text=Ans[2][5], width=6)
    lf3.grid(row=13,column=5)
    lg3 = Label(text=Ans[2][6], borderwidth=1, relief='solid', width=6)
    lg3.grid(row=13,column=6)
    lh3 = Label(text=Ans[2][7], borderwidth=1, relief='solid', width=6)
    lh3.grid(row=13,column=7)
    li3 = Label(text=Ans[2][8], borderwidth=1, relief='solid', width=6)
    li3.grid(row=13,column=8)

    la4 = Label(text=Ans[3][0], width=6)
    la4.grid(row=14,column=0)
    lb4 = Label(text=Ans[3][1], width=6)
    lb4.grid(row=14,column=1)
    lc4 = Label(text=Ans[3][2], width=6)
    lc4.grid(row=14,column=2)
    ld4 = Label(text=Ans[3][3], borderwidth=1, relief='solid', width=6)
    ld4.grid(row=14,column=3)
    le4 = Label(text=Ans[3][4], borderwidth=1, relief='solid', width=6)
    le4.grid(row=14,column=4)
    lf4 = Label(text=Ans[3][5], borderwidth=1, relief='solid', width=6)
    lf4.grid(row=14,column=5)
    lg4 = Label(text=Ans[3][6], width=6)
    lg4.grid(row=14,column=6)
    lh4 = Label(text=Ans[3][7], width=6)
    lh4.grid(row=14,column=7)
    li4 = Label(text=Ans[3][8], width=6)
    li4.grid(row=14,column=8)

    la5 = Label(text=Ans[4][0], width=6)
    la5.grid(row=15,column=0)
    lb5 = Label(text=Ans[4][1], width=6)
    lb5.grid(row=15,column=1)
    lc5 = Label(text=Ans[4][2], width=6)
    lc5.grid(row=15,column=2)
    ld5 = Label(text=Ans[4][3], borderwidth=1, relief='solid', width=6)
    ld5.grid(row=15,column=3)
    le5 = Label(text=Ans[4][4], borderwidth=1, relief='solid', width=6)
    le5.grid(row=15,column=4)
    lf5 = Label(text=Ans[4][5], borderwidth=1, relief='solid', width=6)
    lf5.grid(row=15,column=5)
    lg5 = Label(text=Ans[4][6], width=6)
    lg5.grid(row=15,column=6)
    lh5 = Label(text=Ans[4][7], width=6)
    lh5.grid(row=15,column=7)
    li5 = Label(text=Ans[4][8], width=6)
    li5.grid(row=15,column=8)

    la6 = Label(text=Ans[5][0], width=6)
    la6.grid(row=16,column=0)
    lb6 = Label(text=Ans[5][1], width=6)
    lb6.grid(row=16,column=1)
    lc6 = Label(text=Ans[5][2], width=6)
    lc6.grid(row=16,column=2)
    ld6 = Label(text=Ans[5][3], borderwidth=1, relief='solid', width=6)
    ld6.grid(row=16,column=3)
    le6 = Label(text=Ans[5][4], borderwidth=1, relief='solid', width=6)
    le6.grid(row=16,column=4)
    lf6 = Label(text=Ans[5][5], borderwidth=1, relief='solid', width=6)
    lf6.grid(row=16,column=5)
    lg6 = Label(text=Ans[5][6], width=6)
    lg6.grid(row=16,column=6)
    lh6 = Label(text=Ans[5][7], width=6)
    lh6.grid(row=16,column=7)
    li6 = Label(text=Ans[5][8], width=6)
    li6.grid(row=16,column=8)

    la7 = Label(text=Ans[6][0], borderwidth=1, relief='solid', width=6)
    la7.grid(row=17,column=0)
    lb7 = Label(text=Ans[6][1], borderwidth=1, relief='solid', width=6)
    lb7.grid(row=17,column=1)
    lc7 = Label(text=Ans[6][2], borderwidth=1, relief='solid', width=6)
    lc7.grid(row=17,column=2)
    ld7 = Label(text=Ans[6][3], width=6)
    ld7.grid(row=17,column=3)
    le7 = Label(text=Ans[6][4], width=6)
    le7.grid(row=17,column=4)
    lf7 = Label(text=Ans[6][5], width=6)
    lf7.grid(row=17,column=5)
    lg7 = Label(text=Ans[6][6], borderwidth=1, relief='solid', width=6)
    lg7.grid(row=17,column=6)
    lh7 = Label(text=Ans[6][7], borderwidth=1, relief='solid', width=6)
    lh7.grid(row=17,column=7)
    li7 = Label(text=Ans[6][8], borderwidth=1, relief='solid', width=6)
    li7.grid(row=17,column=8)

    la8 = Label(text=Ans[7][0], borderwidth=1, relief='solid', width=6)
    la8.grid(row=18,column=0)
    lb8 = Label(text=Ans[7][1], borderwidth=1, relief='solid', width=6)
    lb8.grid(row=18,column=1)
    lc8 = Label(text=Ans[7][2], borderwidth=1, relief='solid', width=6)
    lc8.grid(row=18,column=2)
    ld8 = Label(text=Ans[7][3], width=6)
    ld8.grid(row=18,column=3)
    le8 = Label(text=Ans[7][4], width=6)
    le8.grid(row=18,column=4)
    lf8 = Label(text=Ans[7][5], width=6)
    lf8.grid(row=18,column=5)
    lg8 = Label(text=Ans[7][6], borderwidth=1, relief='solid', width=6)
    lg8.grid(row=18,column=6)
    lh8 = Label(text=Ans[7][7], borderwidth=1, relief='solid', width=6)
    lh8.grid(row=18,column=7)
    li8 = Label(text=Ans[7][8], borderwidth=1, relief='solid', width=6)
    li8.grid(row=18,column=8)

    la9 = Label(text=Ans[8][0], borderwidth=1, relief='solid', width=6)
    la9.grid(row=19,column=0)
    lb9 = Label(text=Ans[8][1], borderwidth=1, relief='solid', width=6)
    lb9.grid(row=19,column=1)
    lc9 = Label(text=Ans[8][2], borderwidth=1, relief='solid', width=6)
    lc9.grid(row=19,column=2)
    ld9 = Label(text=Ans[8][3], width=6)
    ld9.grid(row=19,column=3)
    le9 = Label(text=Ans[8][4], width=6)
    le9.grid(row=19,column=4)
    lf9 = Label(text=Ans[8][5], width=6)
    lf9.grid(row=19,column=5)
    lg9 = Label(text=Ans[8][6], borderwidth=1, relief='solid', width=6)
    lg9.grid(row=19,column=6)
    lh9 = Label(text=Ans[8][7], borderwidth=1, relief='solid', width=6)
    lh9.grid(row=19,column=7)
    li9 = Label(text=Ans[8][8], borderwidth=1, relief='solid', width=6)
    li9.grid(row=19,column=8)

btn3=Button(root, text='SOLVE', width='5', height='1', command=assign)
btn3.grid(row=9, column=4)


root.mainloop()
